# %% [markdown]
# <h1 style="text-align:center;">Saving a Machine Learning Model</h1>

# %% [markdown]
# <u>**Author</u> :** [Younes Dahami](https://www.linkedin.com/in/dahami/)

# %% [markdown]
# # Introduction
#
# If we need to solve a familiar problem on a different set of data with the same characteristics, we can reuse the machine learning model we made before. However, to use it again, we have to save it first. In this guide, I'll show you how to save a machine learning model using Python.

# %% [markdown]
# # Why Should We Save a Machine Learning Model ?
#
# After we've trained a machine learning model, saving it allows us to reuse it later for testing on new data or for comparing its performance against other models. We can also deploy a saved model in our final application.
#
# There are several ways to save a machine learning model. If you're new to this, the following section will show you a simple method for saving and reusing a machine learning model using Python.

# %% [markdown]
# # Steps for Saving a Machine Learning Model
#
# Here are the steps for saving a machine learning model :
#
#    * 1) Train the model
#    * 2) Convert it into a byte stream (pickling)
#    * 3) Save the byte stream as a binary file
#
# In Python, converting a machine learning model into a byte stream is called **pickling**. If you want to use the saved model again, you'll need to convert the byte stream file back into a usable machine learning model, which is called **unpickling**.
#
# Now, let's look at how to save a machine learning model. First, I'll train a linear regression model, and then I'll save it using the `pickle` method in Python.

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import sklearn.metrics

df_raw = pd.read_csv("student-mat.csv", usecols= ["G1", "G2", "G3", "studytime", "failures", "absences"], delimiter=";")
df = df_raw.copy()
df.head()
# Out:
#    studytime  failures  absences  G1  G2  G3
# 0          2         0         6   5   6   6
# 1          2         0         4   5   5   6
# 2          2         3        10   7   8  10
# 3          3         0         2  15  14  15
# 4          2         0         4   6  10  10

# %%
# Predicting G3 using all the other features :
X = df.drop(["G3"], axis= 1)
y = df["G3"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=25)

# %%
# Building the model
lr = LinearRegression()
model = lr.fit(X_train, y_train)

# %% [markdown]
# Let's try now to save the model :

# %%
import pickle
with open("pickle_model", "wb") as file :
    pickle.dump(model, file)

# %% [markdown]
# After saving the model, you'll notice a new file named 'pickle_model' in the same directory as your Python file. If you wish to use the saved model for predicting values on the test set, you can execute the code provided below :

# %%
with open("pickle_model", "rb") as file :
    model = pickle.load(file)
    
y_pred = model.predict(X_test)

for i in range(len(y_pred)) :
    print(f"from the feature values : {X_test.values[i]} :\n\
    We predicted {y_pred[i]} whereas the ground truth is equal to {y_test.values[i]}\n")
# Out:
# from the feature values : [ 2  1 20  9  7] :
#     We predicted 6.993000076710688 whereas the ground truth is equal to 8
#
# from the feature values : [2 0 2 9 9] :
#     We predicted 8.499979723084424 whereas the ground truth is equal to 10
#
# from the feature values : [ 1  0  0 13 12] :
#     We predicted 11.943804832336147 whereas the ground truth is equal to 12
#
# from the feature values : [ 1  0  4 10 10] :
#     We predicted 9.768384409517207 whereas the ground truth is equal to 10
#
# from the feature values : [ 1  0 30  8  8] :
#     We predicted 8.57303154984166 whereas the ground truth is equal to 8
#
# from the feature values : [ 2  0 12  7  8] :
#     We predicted 7.6635324933066915 whereas the ground truth is equal to 8
#
# from the feature values : [ 3  0  6 13 12] :
#     We predicted 12.006910607321059 whereas the ground truth is equal to 12
#
# from the feature values : [ 3  0  1 12 14] :
#     We predicted 13.656419640655834 whereas the ground truth is equal to 15
#
# from the feature values : [ 1  3  3 10  8] :
#     We predicted 7.0342085620309796 whereas the ground truth is equal to 7
#
# from the feature values : [ 2  0  0 13 13] :
#     We predicted 12.84146639823403 whereas the ground truth is equal to 12
#
# from the feature values : [ 1  0  3 14 15] :
#     We predicted 15.132042239536121 whereas the ground truth is equal to 16
#
# from the feature values : [ 1  0  8 14 13] :
#     We predicted 13.360809263609296 whereas the ground truth is equal to 13
#
# from the feature values : [ 1  0  5 16 15] :
#     We predicted 15.453521362952158 whereas the ground truth is equal to 16
#
# from the feature values : [ 2  1  8 14 12] :
#     We predicted 12.049210039045976 whereas the ground truth is equal to 12
#
# from the feature values : [2 2 2 8 6] :
#     We predicted 4.942889735323309 whereas the ground truth is equal to 5
#
# from the feature values : [1 3 0 5 0] :
#     We predicted -1.5567022943038749 whereas the ground truth is equal to 0
#
# from the feature values : [1 0 5 7 6] :
#     We predicted 5.50960605784368 whereas the ground truth is equal to 7
#
# from the feature values : [ 3  0  1 13 12] :
#     We predicted 11.811832511741208 whereas the ground truth is equal to 12
#
# from the feature values : [ 1  0  4 10 13] :
#     We predicted 12.717851016777217 whereas the ground truth is equal to 14
#
# from the feature values : [2 2 6 5 9] :
#     We predicted 7.683246991271055 whereas the ground truth is equal to 7
#
# from the feature values : [ 2  1 16  9  8] :
#     We predicted 7.820093136000143 whereas the ground truth is equal to 7
#
# from the feature values : [ 3  0  4 14 14] :
#     We predicted 14.016914383187842 whereas the ground truth is equal to 14
#
# from the feature values : [ 2  0  0 11 11] :
#     We predicted 10.631707441543258 whereas the ground truth is equal to 10
#
# from the feature values : [ 2  1 22 13 10] :
#     We predicted 10.507393692570835 whereas the ground truth is equal to 11
#
# from the feature values : [ 1  0  2 11 12] :
#     We predicted 11.77838818538399 whereas the ground truth is equal to 11
#
# from the feature values : [2 0 2 8 9] :
#     We predicted 8.378255780492376 whereas the ground truth is equal to 8
#
# from the feature values : [2 0 0 9 0] :
#     We predicted -0.4264513369275511 whereas the ground truth is equal to 0
#
# from the feature values : [1 1 0 6 8] :
#     We predicted 6.916165372223928 whereas the ground truth is equal to 8
#
# from the feature values : [ 2  0  2 14 13] :
#     We predicted 13.04122157905802 whereas the ground truth is equal to 13
#
# from the feature values : [ 2  0  0 12 11] :
#     We predicted 10.753431384135306 whereas the ground truth is equal to 12
#
# from the feature values : [ 3  0  3  9 12] :
#     We predicted 11.402967979604952 whereas the ground truth is equal to 11
#
# from the feature values : [ 2  0  0 12 12] :
#     We predicted 11.736586919888643 whereas the ground truth is equal to 11
#
# from the feature values : [ 2  0  4 10  9] :
#     We predicted 8.699734903908414 whereas the ground truth is equal to 11
#
# from the feature values : [ 4  0  6 18 18] :
#     We predicted 18.428969564945874 whereas the ground truth is equal to 18
#
# from the feature values : [ 2  0 10 11 12] :
#     We predicted 12.005019168456297 whereas the ground truth is equal to 13
#
# from the feature values : [ 2  1  4 10 12] :
#     We predicted 11.406251792213899 whereas the ground truth is equal to 12
#
# from the feature values : [ 2  0  0  7 10] :
#     We predicted 9.161656135421723 whereas the ground truth is equal to 11
#
# from the feature values : [ 2  1  6 10 13] :
#     We predicted 12.467438566199176 whereas the ground truth is equal to 13
#
# from the feature values : [1 1 0 7 6] :
#     We predicted 5.071578243309302 whereas the ground truth is equal to 0
#
# from the feature values : [ 2  0 75 10  9] :
#     We predicted 11.4698438611423 whereas the ground truth is equal to 9
#
# from the feature values : [ 2  1 18 12 10] :
#     We predicted 10.229607273514906 whereas the ground truth is equal to 10
#
# from the feature values : [1 0 8 9 9] :
#     We predicted 8.8195674076357 whereas the ground truth is equal to 10
#
# from the feature values : [ 2  0  0 14 14] :
#     We predicted 13.946345876579416 whereas the ground truth is equal to 14
#
# from the feature values : [ 3  1  0  7 10] :
#     We predicted 8.833212446611741 whereas the ground truth is equal to 10
#
# from the feature values : [ 1  0 14  6  5] :
#     We predicted 4.755867151542025 whereas the ground truth is equal to 5
#
# from the feature values : [2 0 0 6 7] :
#     We predicted 6.090465585569662 whereas the ground truth is equal to 0
#
# from the feature values : [ 2  0  0 15 15] :
#     We predicted 15.051225354924801 whereas the ground truth is equal to 15
#
# from the feature values : [2 0 8 8 8] :
#     We predicted 7.6291939594348595 whereas the ground truth is equal to 6
#
# from the feature values : [ 3  0  0 18 16] :
#     We predicted 16.314058748598832 whereas the ground truth is equal to 16
#
# from the feature values : [ 4  0  1 12 12] :
#     We predicted 11.604614599293704 whereas the ground truth is equal to 12
#
# from the feature values : [ 4  0  6 11 13] :
#     We predicted 12.661124288034843 whereas the ground truth is equal to 14
#
# from the feature values : [2 0 2 8 9] :
#     We predicted 8.378255780492376 whereas the ground truth is equal to 10
#
# from the feature values : [1 1 0 6 5] :
#     We predicted 3.9666987649639154 whereas the ground truth is equal to 0
#
# from the feature values : [ 2  0  2 11  8] :
#     We predicted 7.7602720725151855 whereas the ground truth is equal to 8
#
# from the feature values : [ 3  2  4 15 14] :
#     We predicted 13.652738887870838 whereas the ground truth is equal to 15
#
# from the feature values : [ 2  0  0  8 10] :
#     We predicted 9.283380078013773 whereas the ground truth is equal to 12
#
# from the feature values : [ 3  0  0  9 10] :
#     We predicted 9.319610050750367 whereas the ground truth is equal to 0
#
# from the feature values : [ 2  0  2 15 15] :
#     We predicted 15.129256593156741 whereas the ground truth is equal to 16
#
# from the feature values : [ 3  0  2 10  9] :
#     We predicted 8.536209695821018 whereas the ground truth is equal to 8
#
# from the feature values : [ 2  0  0 16 18] :
#     We predicted 18.122415904776865 whereas the ground truth is equal to 18
#
# from the feature values : [ 1  1 38  8  9] :
#     We predicted 9.62536231956823 whereas the ground truth is equal to 8
#
# from the feature values : [3 1 0 6 5] :
#     We predicted 3.795710825253005 whereas the ground truth is equal to 0
#
# from the feature values : [ 2  0  0 14 15] :
#     We predicted 14.929501412332753 whereas the ground truth is equal to 15
#
# from the feature values : [ 3  0  8 13 11] :
#     We predicted 11.101786309799662 whereas the ground truth is equal to 11
#
# from the feature values : [ 2  0  2 15 15] :
#     We predicted 15.129256593156741 whereas the ground truth is equal to 14
#
# from the feature values : [ 2  0  2 16 16] :
#     We predicted 16.234136071502128 whereas the ground truth is equal to 16
#
# from the feature values : [ 3  0  0 16 15] :
#     We predicted 15.087455327661397 whereas the ground truth is equal to 15
#
# from the feature values : [2 3 0 8 7] :
#     We predicted 5.605064313890178 whereas the ground truth is equal to 0
#
# from the feature values : [ 1  0  4  8 10] :
#     We predicted 9.524936524333109 whereas the ground truth is equal to 10
#
# from the feature values : [ 1  1 14  6  5] :
#     We predicted 4.512917432587499 whereas the ground truth is equal to 5
#
# from the feature values : [ 2  0  4 10  9] :
#     We predicted 8.699734903908414 whereas the ground truth is equal to 9
#
# from the feature values : [ 2  0 10 14 12] :
#     We predicted 12.370190996232443 whereas the ground truth is equal to 11
#
# from the feature values : [4 0 0 7 9] :
#     We predicted 8.007512659957476 whereas the ground truth is equal to 0
#
# from the feature values : [ 1  0  2 14 14] :
#     We predicted 14.109871084666812 whereas the ground truth is equal to 14
#
# from the feature values : [ 1  0 22  9  9] :
#     We predicted 9.365786075259285 whereas the ground truth is equal to 9
#
# from the feature values : [ 2  0  0 14 15] :
#     We predicted 14.929501412332753 whereas the ground truth is equal to 15
#
# from the feature values : [1 0 7 6 5] :
#     We predicted 4.482757817730234 whereas the ground truth is equal to 6
#
# from the feature values : [ 4  0  6 10 10] :
#     We predicted 9.589933738182781 whereas the ground truth is equal to 11
#
# from the feature values : [ 3  0  7 15 16] :
#     We predicted 16.221996254634476 whereas the ground truth is equal to 15

# %% [markdown]
# # Summary
#
# That's the process for saving a machine learning model as a byte stream, making it usable for future tasks on new datasets. I hope you found this guide helpful on how to save a machine learning model using Python.

# %% [markdown]
# # Change Log
#
# | Date (DD-MM-YYYY) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 15-03-2024       | 1.0     | Younes Dahami   |  initial version |
